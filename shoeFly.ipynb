# %% [markdown]
# # A/B Testing for ShoeFly.com
#
# An A/B Test is performed in this online shoe store. They have two different versions of an ad, which they have placed in emails and banner ads on Facebook, Twitter, and Google. For this exercise, they wanted to know how the two ads are performing on each of their different platforms on each day of the week.
#
# ## Useful information
#
# - `user_id`: _unique number_ that identifies each user
# - `utm_source`: tells from what UTM (Urchin Tracking Module) the ad click comes from - (Google, Facebook, Twitter(X), email)
# - `day`: The day the user clicked the ad
# - `ad_click_timestamp`: the time that the ad platform was clicked
# - `experimental_group`: The two ads being tested - whether the user was shown ad A or ad B

# %% [markdown]
# ### Step 1
#
# I started by looking at the data and examining the first five rows.

# %%
import pandas as pd

ad_clicks = pd.read_csv('shoefly_data.csv')
styled_underline = ad_clicks.style.set_table_styles(
    [{'selector': ' thead th', 'props': [('border-bottom', '2px solid black')]}]
)
styled_underline
# Out:
# <style type="text/css">
# #T_80396  thead th {
#   border-bottom: 2px solid black;
# }
# </style>
# <table id="T_80396">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80396_level0_col0" class="col_heading level0 col0" >user_id</th>
#       <th id="T_80396_level0_col1" class="col_heading level0 col1" >utm_source</th>
#       <th id="T_80396_level0_col2" class="col_heading level0 col2" >day</th>
#       <th id="T_80396_level0_col3" class="col_heading level0 col3" >ad_click_timestamp</th>
#       <th id="T_80396_level0_col4" class="col_heading level0 col4" >experimental_group</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80396_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_80396_row0_col0" class="data row0 col0" >008b7c6c-7272-471e-b90e-930d548bd8d7</td>
#       <td id="T_80396_row0_col1" class="data row0 col1" >google</td>
#       <td id="T_80396_row0_col2" class="data row0 col2" >6 - Saturday</td>
#       <td id="T_80396_row0_col3" class="data row0 col3" >7:18</td>
#       <td id="T_80396_row0_col4" class="data row0 col4" >A</td>
#     </tr>
#     <tr>
#       <th id="T_80396_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_80396_row1_col0" class="data row1 col0" >009abb94-5e14-4b6c-bb1c-4f4df7aa7557</td>
#       <td id="T_80396_row1_col1" class="data row1 col1" >facebook</td>
#       <td id="T_80396_row1_col2" class="data row1 col2" >7 - Sunday</td>
#       <td id="T_80396_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_80396_row1_col4" class="data row1 col4" >B</td>
#     </tr>
#     <tr>
#       <th id="T_80396_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_80396_row2_col0" class="data row2 col0" >00f5d532-ed58-4570-b6d2-768df5f41aed</td>
#       <td id="T_80396_row2_col1" class="data row2 col1" >twitter</td>
#       <td id="T_80396_row2_col2" class="data row2 col2" >2 - Tuesday</td>
#       <td id="T_80396_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_80396_row2_col4" class="data row2 col4" >A</td>
#     </tr>
#     <tr>
#       <th id="T_80396_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_80396_row3_col0" class="data row3 col0" >011adc64-0f44-4fd9-a0bb-f1506d2ad439</td>
#       <td id="T_80396_row3_col1" class="data row3 col1" >google</td>
#       <td id="T_80396_row3_col2" class="data row3 col2" >2 - Tuesday</td>
#       <td id="T_80396_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_80396_row3_col4" class="data row3 col4" >B</td>
#     </tr>
#     <tr>
#       <th id="T_80396_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_80396_row4_col0" class="data row4 col0" >012137e6-7ae7-4649-af68-205b4702169c</td>
#       <td id="T_80396_row4_col1" class="data row4 col1" >facebook</td>
#       <td id="T_80396_row4_col2" class="data row4 col2" >7 - Sunday</td>
#       <td id="T_80396_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_80396_row4_col4" class="data row4 col4" >B</td>
#     </tr>
#     <tr>
#       <th id="T_80396_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_80396_row5_col0" class="data row5 col0" >013b0072-7b72-40e7-b698-98b4d0c9967f</td>
#       <td id="T_80396_row5_col1" class="data row5 col1" >facebook</td>
#       <td id="T_80396_row5_col2" class="data row5 col2" >1 - Monday</td>
#       <td id="T_80396_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_80396_row5_col4" class="data row5 col4" >A</td>
#     </tr>
#     <tr>
#       <th id="T_80396_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_80396_row6_col0" class="data row6 col0" >0153d85b-7660-4c39-92eb-1e1acd023280</td>
#       <td id="T_80396_row6_col1" class="data row6 col1" >google</td>
#       <td id="T_80396_row6_col2" class="data row6 col2" >4 - Thursday</td>
#       <td id="T_80396_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_80396_row6_col4" class="data row6 col4" >A</td>
#     </tr>
#     <tr>
#       <th id="T_80396_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_80396_row7_col0" class="data row7 col0" >01555297-d6e6-49ae-aeba-1b196fdbb09f</td>
#       <td id="T_80396_row7_col1" class="data row7 col1" >google</td>
#       <td id="T_80396_row7_col2" class="data row7 col2" >3 - Wednesday</td>
#       <td id="T_80396_row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_80396_row7_col4" class="data row7 col4" >A</td>
#     </tr>
#     <tr>
#       <th id="T_80396_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_80396_row8_col0" class="data row8 col0" >018cea61-19ea-4119-895b-1a4309ccb148</td>
#       <td id="T_80396_row8_col1" class="data row8 col1" >email</td>
#       <td id="T_80396_row8_col2" class="data row8 col2" >1 - Monday</td>
#       <td id="T_80396_row8_col3" class="data row8 col3" >18:33</td>
#       <td id="T_80396_row8_col4" class="data row8 col4" >A</td>
#     </tr>
#     <tr>
#       <th id="T_80396_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_80396_row9_col0" class="data row9 col0" >01a210c3-fde0-4e6f-8efd-4f0e38730ae6</td>
#       <td id="T_80396_row9_col1" class="data row9 col1" >email</td>
#       <td id="T_80396_row9_col2" class="data row9 col2" >2 - Tuesday</td>
#       <td id="T_80396_row9_col3" class="data row9 col3" >15:21</td>
#       <td id="T_80396_row9_col4" class="data row9 col4" >B</td>
#     </tr>
#     <tr>
#       <th id="T_80396_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_80396_row10_col0" class="data row10 col0" >01adb2e7-f711-4ae4-a7c6-29f48457eea1</td>
#       <td id="T_80396_row10_col1" class="data row10 col1" >google</td>
#       <td id="T_80396_row10_col2" class="data row10 col2" >3 - Wednesday</td>
#       <td id="T_80396_row10_col3" class="data row10 col3" >nan</td>
#       <td id="T_80396_row10_col4" class="data row10 col4" >B</td>
#     </tr>
#     <tr>
#       <th id="T_80396_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_80396_row11_col0" class="data row11 col0" >01ae0361-7d17-4760-a2c8-23977a46fb78</td>
#       <td id="T_80396_row11_col1" class="data row11 col1" >facebook</td>
#       <td id="T_80396_row11_col2" class="data row11 col2" >4 - Thursday</td>
#       <td id="T_80396_row11_col3" class="data row11 col3" >7:11</td>
#       <td id="T_80396_row11_col4" class="data row11 col4" >B</td>
#     </tr>
#     <tr>
#       <th id="T_80396_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_80396_row12_col0" class="data row12 col0" >01fb228a-9d28-4cde-932c-59b933fa763b</td>
#       <td id="T_80396_row12_col1" class="data row12 col1" >email</td>
#       <td id="T_80396_row12_col2" class="data row12 col2" >7 - Sunday</td>
#       <td id="T_80396_row12_col3" class="data row12 col3" >nan</td>
#       <td id="T_80396_row12_col4" class="data row12 col4" >A</td>
#     </tr>
#     <tr>
#       <th id="T_80396_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_80396_row13_col0" class="data row13 col0" >023598b8-09e2-40ed-9c90-34d607094ff9</td>
#       <td id="T_80396_row13_col1" class="data row13 col1" >google</td>
#       <td id="T_80396_row13_col2" class="data row13 col2" >2 - Tuesday</td>
#       <td id="T_80396_row13_col3" class="data row13 col3" >nan</td>
#       <td id="T_80396_row13_col4" class="data row13 col4" >B</td>
#     </tr>
#     <tr>
#       <th id="T_80396_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_80396_row14_col0" class="data row14 col0" >02405d93-9c33-4034-894a-b9523956a3ad</td>
#       <td id="T_80396_row14_col1" class="data row14 col1" >twitter</td>
#       <td id="T_80396_row14_col2" class="data row14 col2" >2 - Tuesday</td>
#       <td id="T_80396_row14_col3" class="data row14 col3" >nan</td>
#       <td id="T_80396_row14_col4" class="data row14 col4" >A</td>
#     </tr>
#     <tr>
#       <th id="T_80396_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_80396_row15_col0" class="data row15 col0" >0254b59f-082d-4a5a-913d-4f2bba267768</td>
#       <td id="T_80396_row15_col1" class="data row15 col1" >google</td>
#       <td id="T_80396_row15_col2" class=

# %% [markdown]
# ### Step 2
#
# The manager wanted to know which ad platform was getting the most views so I examined how many views came from each UTM source creating a Series.

# %%
counting_views = ad_clicks.groupby('utm_source').user_id.count()
counting_views
# Out:
# utm_source
# email       255
# facebook    504
# google      680
# twitter     215
# Name: user_id, dtype: int64

# %% [markdown]
# _Google was the most visited platform._

# %% [markdown]
# ### Step 3
#
# Checking whether the ad click timestamps are not null. If they are, this means that someone clicked on the ad that was displayed.
# `True` means that a user clicked on the ad, `False` tell us otherwise.

# %%
new_column_is_click = ad_clicks['is_click'] = ad_clicks['ad_click_timestamp'].notnull()
new_column_is_click
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1649    False
# 1650    False
# 1651    False
# 1652     True
# 1653    False
# Name: ad_click_timestamp, Length: 1654, dtype: bool

# %% [markdown]
# ### Step 4
#
# Now I wanted to know the **number of people** who clicked on ads from each UTM source.

# %%
clicks_by_source = ad_clicks.groupby(['utm_source', 'is_click']).user_id.count().reset_index()
styled_underline = clicks_by_source.style.set_table_styles(
    [{'selector': ' thead th', 'props': [('border-bottom', '2px solid black')]}]
)
styled_underline
# Out:
# <style type="text/css">
# #T_b06aa  thead th {
#   border-bottom: 2px solid black;
# }
# </style>
# <table id="T_b06aa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b06aa_level0_col0" class="col_heading level0 col0" >utm_source</th>
#       <th id="T_b06aa_level0_col1" class="col_heading level0 col1" >is_click</th>
#       <th id="T_b06aa_level0_col2" class="col_heading level0 col2" >user_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b06aa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b06aa_row0_col0" class="data row0 col0" >email</td>
#       <td id="T_b06aa_row0_col1" class="data row0 col1" >False</td>
#       <td id="T_b06aa_row0_col2" class="data row0 col2" >175</td>
#     </tr>
#     <tr>
#       <th id="T_b06aa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b06aa_row1_col0" class="data row1 col0" >email</td>
#       <td id="T_b06aa_row1_col1" class="data row1 col1" >True</td>
#       <td id="T_b06aa_row1_col2" class="data row1 col2" >80</td>
#     </tr>
#     <tr>
#       <th id="T_b06aa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b06aa_row2_col0" class="data row2 col0" >facebook</td>
#       <td id="T_b06aa_row2_col1" class="data row2 col1" >False</td>
#       <td id="T_b06aa_row2_col2" class="data row2 col2" >324</td>
#     </tr>
#     <tr>
#       <th id="T_b06aa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b06aa_row3_col0" class="data row3 col0" >facebook</td>
#       <td id="T_b06aa_row3_col1" class="data row3 col1" >True</td>
#       <td id="T_b06aa_row3_col2" class="data row3 col2" >180</td>
#     </tr>
#     <tr>
#       <th id="T_b06aa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b06aa_row4_col0" class="data row4 col0" >google</td>
#       <td id="T_b06aa_row4_col1" class="data row4 col1" >False</td>
#       <td id="T_b06aa_row4_col2" class="data row4 col2" >441</td>
#     </tr>
#     <tr>
#       <th id="T_b06aa_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b06aa_row5_col0" class="data row5 col0" >google</td>
#       <td id="T_b06aa_row5_col1" class="data row5 col1" >True</td>
#       <td id="T_b06aa_row5_col2" class="data row5 col2" >239</td>
#     </tr>
#     <tr>
#       <th id="T_b06aa_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b06aa_row6_col0" class="data row6 col0" >twitter</td>
#       <td id="T_b06aa_row6_col1" class="data row6 col1" >False</td>
#       <td id="T_b06aa_row6_col2" class="data row6 col2" >149</td>
#     </tr>
#     <tr>
#       <th id="T_b06aa_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b06aa_row7_col0" class="data row7 col0" >twitter</td>
#       <td id="T_b06aa_row7_col1" class="data row7 col1" >True</td>
#       <td id="T_b06aa_row7_col2" class="data row7 col2" >66</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# _Google got the greater number of people that clicked on an ad, with 239 clicks. In turn Twitter is the platform with least number of people that clicked on an ad, with 66 clicks._

# %% [markdown]
# ### Step 5
#
# Pivoting the table for better readability.

# %%
clicks_pivot = clicks_by_source.pivot(
    columns = 'is_click',
    index='utm_source',
    values='user_id'
)
styled_underline = clicks_pivot.style.set_table_styles(
    [{'selector': ' thead th', 'props': [('border-bottom', '2px solid black')]}]
)
styled_underline
# Out:
# <style type="text/css">
# #T_038dc  thead th {
#   border-bottom: 2px solid black;
# }
# </style>
# <table id="T_038dc">
#   <thead>
#     <tr>
#       <th class="index_name level0" >is_click</th>
#       <th id="T_038dc_level0_col0" class="col_heading level0 col0" >False</th>
#       <th id="T_038dc_level0_col1" class="col_heading level0 col1" >True</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >utm_source</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_038dc_level0_row0" class="row_heading level0 row0" >email</th>
#       <td id="T_038dc_row0_col0" class="data row0 col0" >175</td>
#       <td id="T_038dc_row0_col1" class="data row0 col1" >80</td>
#     </tr>
#     <tr>
#       <th id="T_038dc_level0_row1" class="row_heading level0 row1" >facebook</th>
#       <td id="T_038dc_row1_col0" class="data row1 col0" >324</td>
#       <td id="T_038dc_row1_col1" class="data row1 col1" >180</td>
#     </tr>
#     <tr>
#       <th id="T_038dc_level0_row2" class="row_heading level0 row2" >google</th>
#       <td id="T_038dc_row2_col0" class="data row2 col0" >441</td>
#       <td id="T_038dc_row2_col1" class="data row2 col1" >239</td>
#     </tr>
#     <tr>
#       <th id="T_038dc_level0_row3" class="row_heading level0 row3" >twitter</th>
#       <td id="T_038dc_row3_col0" class="data row3 col0" >149</td>
#       <td id="T_038dc_row3_col1" class="data row3 col1" >66</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Step 6
#
# Creating a column to calculate the **percentage of users** who clicked on the ad from each UTM source.

# %%
new_column = clicks_pivot['percentage_clicked'] = clicks_pivot[True]/(clicks_pivot[True]+clicks_pivot[False])*100
#converting into 2 decimals
clicks_pivot['percentage_clicked'] = clicks_pivot['percentage_clicked'].round(2)
clicks_pivot
# Out:
# is_click    False  True  percentage_clicked
# utm_source
# email         175    80               31.37
# facebook      324   180               35.71
# google        441   239               35.15
# twitter       149    66               30.70

# %% [markdown]
# ### Step 7: Analyzing an A/B Test
#
# The column `experimental_group` tells us whether the user was shown Ad A or Ad B.
#
# Checking the number of people shown in both ads.

# %%
check_ads = ad_clicks.groupby('experimental_group').user_id.count()
check_ads
# Out:
# experimental_group
# A    827
# B    827
# Name: user_id, dtype: int64

# %% [markdown]
# _The number of users that have shown both ads is the same_.

# %% [markdown]
# ### Step 8
#
# Checking if a greater number of users clicked on ad A or ad B

# %%
check_ads_pencentage = ad_clicks.groupby(['experimental_group', 'is_click']).user_id.count().reset_index()
#print(check_ads_pencentage)

#Pivoting 
pivoted_check_ads_pencentage = check_ads_pencentage.pivot(columns='experimental_group',
index='is_click',
values='user_id')
print(pivoted_check_ads_pencentage)
# Out:
# experimental_group    A    B
# is_click
# False               517  572
# True                310  255

# %% [markdown]
# _At this point, we can verify that 310 of the 827 users who were shown ad A clicked on it, while 255 clicked on ad B. So, a greater number of users clicked on ad A._

# %% [markdown]
# ### Step 9
#
# Checking if the clicks by `experimental_group` have changed by day of the week.

# %%
a_clicks = ad_clicks[ad_clicks.experimental_group == 'A']
b_clicks = ad_clicks[ad_clicks.experimental_group == 'B']
#print(a_clicks)

group_A = a_clicks.groupby(['is_click', 'day']).user_id.count().reset_index()
#print(group_A)

group_B = b_clicks.groupby(['is_click', 'day']).user_id.count().reset_index()
#print(group_B)

#Pivoting both table groups
pivoted_A = group_A.pivot(columns='day',
index='is_click',
values='user_id')

pivoted_B = group_B.pivot(columns='day',
index='is_click',
values='user_id')

print(pivoted_A)
print('\n')
print(pivoted_B)
# Out:
# day       1 - Monday  2 - Tuesday  3 - Wednesday  4 - Thursday  5 - Friday  \
# is_click
# False             70           76             86            69          77
# True              43           43             38            47          51
#
# day       6 - Saturday  7 - Sunday
# is_click
# False               73          66
# True                45          43
#
#
# day       1 - Monday  2 - Tuesday  3 - Wednesday  4 - Thursday  5 - Friday  \
# is_click
# False             81           74             89            87          90
# True              32           45             35            29          38
#
# day       6 - Saturday  7 - Sunday
# is_click
# False               76          75
# True                42          34

# %% [markdown]
# ### Step 10
#
# Calculating the percentage of people, by group, who clicked on the ad by day.

# %%
pivoted_A.loc['percentage_clicked_A_by_day'] = pivoted_A.loc[True] / (pivoted_A.loc[True] + pivoted_A.loc[False]) * 100

print(pivoted_A.loc['percentage_clicked_A_by_day'].round(2))
# Out:
# day
# 1 - Monday       38.05
# 2 - Tuesday      36.13
# 3 - Wednesday    30.65
# 4 - Thursday     40.52
# 5 - Friday       39.84
# 6 - Saturday     38.14
# 7 - Sunday       39.45
# Name: percentage_clicked_A_by_day, dtype: float64

# %% [markdown]
# _Thursday was the day most people on group A clicked on the ad._

# %%
pivoted_B.loc['percentage_clicked_B_by_day'] = pivoted_B.loc[True] / (pivoted_B.loc[True] + pivoted_B.loc[False]) * 100

print(pivoted_B.loc['percentage_clicked_B_by_day'].round(2))
# Out:
# day
# 1 - Monday       28.32
# 2 - Tuesday      37.82
# 3 - Wednesday    28.23
# 4 - Thursday     25.00
# 5 - Friday       29.69
# 6 - Saturday     35.59
# 7 - Sunday       31.19
# Name: percentage_clicked_B_by_day, dtype: float64

# %% [markdown]
# _Tuesday was the day most people on group B clicked on the ad._
